# %%
import os
import random
import shutil

# Paths
source_dir = r'H:\Optima\Annotations'
output_dir = r'H:\Optima\Annotations_Split'

# Define split sizes
num_train = 17
num_val = 3
num_test = 4

# Define the maximum number of patches per class per patient
max_patches_per_class = 500

# Get a list of patients (subfolders in source directory)
patients = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]

# Check for the correct number of patients
if len(patients) != 24:
    raise ValueError("Expected 24 patients but found {}".format(len(patients)))

# Shuffle and split the list of patients
random.shuffle(patients)
train_patients = patients[:num_train]
val_patients = patients[num_train:num_train + num_val]
test_patients = patients[num_train + num_val:]

# Function to copy patches from each patient to the appropriate split/class folder
def copy_patches(patient_list, split_name):
    for patient in patient_list:
        source_patient_dir = os.path.join(source_dir, patient)
        
        # Iterate over each class folder within the patient folder
        for class_folder in os.listdir(source_patient_dir):
            source_class_dir = os.path.join(source_patient_dir, class_folder)
            dest_class_dir = os.path.join(output_dir, split_name, class_folder)
            
            # Check if the class folder exists for this patient
            if not os.path.isdir(source_class_dir):
                print(f"Class folder {class_folder} missing for patient {patient}. Skipping...")
                continue  # Skip to the next class if the folder doesn't exist
            
            # Create destination class folder if it doesn't exist
            os.makedirs(dest_class_dir, exist_ok=True)
            
            # Copy up to max_patches_per_class patches for the class
            patches = os.listdir(source_class_dir)[:max_patches_per_class]
            for patch in patches:
                src_patch_path = os.path.join(source_class_dir, patch)
                dest_patch_path = os.path.join(dest_class_dir, f"{patient}_{patch}")
                shutil.copy(src_patch_path, dest_patch_path)
            print(f"Copied {len(patches)} patches from {class_folder} of {patient} to {split_name}/{class_folder}")

# Copy data for each split
copy_patches(train_patients, "train")
copy_patches(val_patients, "val")
copy_patches(test_patients, "test")

print("Data split complete. Check output directory:", output_dir)
# Out:
# Copied 96 patches from Adipose of TCGA-A2-A0ST-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-A2-A0ST-01Z-00-DX1 to train/Background
# Copied 33 patches from Immune cells of TCGA-A2-A0ST-01Z-00-DX1 to train/Immune cells
# Copied 500 patches from Stroma of TCGA-A2-A0ST-01Z-00-DX1 to train/Stroma
# Copied 42 patches from Tumor of TCGA-A2-A0ST-01Z-00-DX1 to train/Tumor
# Copied 132 patches from Adipose of TCGA-BH-A0B5-01Z-00-DX1 to train/Adipose
# Copied 10 patches from Immune cells of TCGA-BH-A0B5-01Z-00-DX1 to train/Immune cells
# Copied 76 patches from Normal of TCGA-BH-A0B5-01Z-00-DX1 to train/Normal
# Copied 132 patches from Stroma of TCGA-BH-A0B5-01Z-00-DX1 to train/Stroma
# Copied 234 patches from Tumor of TCGA-BH-A0B5-01Z-00-DX1 to train/Tumor
# Copied 495 patches from Background of TCGA-AN-A0FZ-01Z-00-DX1 to train/Background
# Copied 15 patches from Immune cells of TCGA-AN-A0FZ-01Z-00-DX1 to train/Immune cells
# Copied 58 patches from Stroma of TCGA-AN-A0FZ-01Z-00-DX1 to train/Stroma
# Copied 17 patches from Tumor of TCGA-AN-A0FZ-01Z-00-DX1 to train/Tumor
# Copied 204 patches from Adipose of TCGA-AQ-A54O-01Z-00-DX1 to train/Adipose
# Copied 39 patches from Immune cells of TCGA-AQ-A54O-01Z-00-DX1 to train/Immune cells
# Copied 429 patches from Stroma of TCGA-AQ-A54O-01Z-00-DX1 to train/Stroma
# Copied 110 patches from Tumor of TCGA-AQ-A54O-01Z-00-DX1 to train/Tumor
# Copied 500 patches from Adipose of TCGA-4H-AAAK-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-4H-AAAK-01Z-00-DX1 to train/Background
# Copied 60 patches from complex of TCGA-4H-AAAK-01Z-00-DX1 to train/complex
# Copied 33 patches from Immune cells of TCGA-4H-AAAK-01Z-00-DX1 to train/Immune cells
# Copied 12 patches from Normal of TCGA-4H-AAAK-01Z-00-DX1 to train/Normal
# Copied 269 patches from Stroma of TCGA-4H-AAAK-01Z-00-DX1 to train/Stroma
# Copied 383 patches from Tumor of TCGA-4H-AAAK-01Z-00-DX1 to train/Tumor
# Copied 500 patches from Adipose of TCGA-S3-A6ZH-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-S3-A6ZH-01Z-00-DX1 to train/Background
# Copied 80 patches from Stroma of TCGA-S3-A6ZH-01Z-00-DX1 to train/Stroma
# Copied 209 patches from Tumor of TCGA-S3-A6ZH-01Z-00-DX1 to train/Tumor
# Copied 500 patches from Adipose of TCGA-E2-A15C-01Z-00-DX1 to train/Adipose
# Copied 117 patches from Background of TCGA-E2-A15C-01Z-00-DX1 to train/Background
# Copied 130 patches from complex of TCGA-E2-A15C-01Z-00-DX1 to train/complex
# Copied 361 patches from Stroma of TCGA-E2-A15C-01Z-00-DX1 to train/Stroma
# Copied 500 patches from Tumor of TCGA-E2-A15C-01Z-00-DX1 to train/Tumor
# Copied 365 patches from Adipose of TCGA-E2-A1B6-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-E2-A1B6-01Z-00-DX1 to train/Background
# Copied 50 patches from Immune cells of TCGA-E2-A1B6-01Z-00-DX1 to train/Immune cells
# Copied 52 patches from Necrosis of TCGA-E2-A1B6-01Z-00-DX1 to train/Necrosis
# Copied 16 patches from Stroma of TCGA-E2-A1B6-01Z-00-DX1 to train/Stroma
# Copied 71 patches from Tumor of TCGA-E2-A1B6-01Z-00-DX1 to train/Tumor
# Copied 90 patches from Adipose of TCGA-GI-A2C8-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-GI-A2C8-01Z-00-DX1 to train/Background
# Copied 6 patches from complex of TCGA-GI-A2C8-01Z-00-DX1 to train/complex
# Copied 32 patches from Immune cells of TCGA-GI-A2C8-01Z-00-DX1 to train/Immune cells
# Copied 42 patches from Stroma of TCGA-GI-A2C8-01Z-00-DX1 to train/Stroma
# Copied 71 patches from Tumor of TCGA-GI-A2C8-01Z-00-DX1 to train/Tumor
# Copied 204 patches from Adipose of TCGA-B6-A0RT-01Z-00-DX1 to train/Adipose
# Copied 56 patches from complex of TCGA-B6-A0RT-01Z-00-DX1 to train/complex
# Copied 76 patches from Immune cells of TCGA-B6-A0RT-01Z-00-DX1 to train/Immune cells
# Copied 47 patches from Necrosis of TCGA-B6-A0RT-01Z-00-DX1 to train/Necrosis
# Copied 365 patches from Stroma of TCGA-B6-A0RT-01Z-00-DX1 to train/Stroma
# Copied 225 patches from Tumor of TCGA-B6-A0RT-01Z-00-DX1 to train/Tumor
# Copied 86 patches from Adipose of TCGA-AO-A0J8-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-AO-A0J8-01Z-00-DX1 to train/Background
# Copied 12 patches from complex of TCGA-AO-A0J8-01Z-00-DX1 to train/complex
# Copied 8 patches from Immune cells of TCGA-AO-A0J8-01Z-00-DX1 to train/Immune cells
# Copied 55 patches from Normal of TCGA-AO-A0J8-01Z-00-DX1 to train/Normal
# Copied 82 patches from Stroma of TCGA-AO-A0J8-01Z-00-DX1 to train/Stroma
# Copied 21 patches from Tumor of TCGA-AO-A0J8-01Z-00-DX1 to train/Tumor
# Copied 399 patches from Adipose of TCGA-BH-A0H9-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-BH-A0H9-01Z-00-DX1 to train/Background
# Copied 4 patches from Immune cells of TCGA-BH-A0H9-01Z-00-DX1 to train/Immune cells
# Copied 20 patches from Normal of TCGA-BH-A0H9-01Z-00-DX1 to train/Normal
# Copied 188 patches from Stroma of TCGA-BH-A0H9-01Z-00-DX1 to train/Stroma
# Copied 212 patches from Tumor of TCGA-BH-A0H9-01Z-00-DX1 to train/Tumor
# Copied 72 patches from Adipose of TCGA-A7-A13G-01Z-00-DX1 to train/Adipose
# Copied 210 patches from Background of TCGA-A7-A13G-01Z-00-DX1 to train/Background
# Copied 6 patches from complex of TCGA-A7-A13G-01Z-00-DX1 to train/complex
# Copied 10 patches from Stroma of TCGA-A7-A13G-01Z-00-DX1 to train/Stroma
# Copied 20 patches from Tumor of TCGA-A7-A13G-01Z-00-DX1 to train/Tumor
# Copied 288 patches from Adipose of TCGA-EW-A1PD-01Z-00-DX1 to train/Adipose
# Copied 45 patches from complex of TCGA-EW-A1PD-01Z-00-DX1 to train/complex
# Copied 52 patches from Immune cells of TCGA-EW-A1PD-01Z-00-DX1 to train/Immune cells
# Copied 13 patches from Necrosis of TCGA-EW-A1PD-01Z-00-DX1 to train/Necrosis
# Copied 147 patches from Normal of TCGA-EW-A1PD-01Z-00-DX1 to train/Normal
# Copied 212 patches from Stroma of TCGA-EW-A1PD-01Z-00-DX1 to train/Stroma
# Copied 50 patches from Tumor of TCGA-EW-A1PD-01Z-00-DX1 to train/Tumor
# Copied 500 patches from Adipose of TCGA-WT-AB44-01Z-00-DX1 to train/Adipose
# Copied 56 patches from complex of TCGA-WT-AB44-01Z-00-DX1 to train/complex
# Copied 36 patches from Normal of TCGA-WT-AB44-01Z-00-DX1 to train/Normal
# Copied 108 patches from Stroma of TCGA-WT-AB44-01Z-00-DX1 to train/Stroma
# Copied 400 patches from Tumor of TCGA-WT-AB44-01Z-00-DX1 to train/Tumor
# Copied 288 patches from Adipose of TCGA-E9-A6HE-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-E9-A6HE-01Z-00-DX1 to train/Background
# Copied 12 patches from complex of TCGA-E9-A6HE-01Z-00-DX1 to train/complex
# Copied 4 patches from Immune cells of TCGA-E9-A6HE-01Z-00-DX1 to train/Immune cells
# Copied 91 patches from Stroma of TCGA-E9-A6HE-01Z-00-DX1 to train/Stroma
# Copied 133 patches from Tumor of TCGA-E9-A6HE-01Z-00-DX1 to train/Tumor
# Copied 100 patches from Adipose of TCGA-LQ-A4E4-01Z-00-DX1 to train/Adipose
# Copied 500 patches from Background of TCGA-LQ-A4E4-01Z-00-DX1 to train/Background
# Copied 36 patches from complex of TCGA-LQ-A4E4-01Z-00-DX1 to train/complex
# Copied 156 patches from Immune cells of TCGA-LQ-A4E4-01Z-00-DX1 to train/Immune cells
# Copied 42 patches from Stroma of TCGA-LQ-A4E4-01Z-00-DX1 to train/Stroma
# Copied 88 patches from Tumor of TCGA-LQ-A4E4-01Z-00-DX1 to train/Tumor
# Copied 60 patches from Adipose of TCGA-A8-A08H-01Z-00-DX1 to val/Adipose
# Copied 500 patches from Background of TCGA-A8-A08H-01Z-00-DX1 to val/Background
# Copied 49 patches from complex of TCGA-A8-A08H-01Z-00-DX1 to val/complex
# Copied 30 patches from Immune cells of TCGA-A8-A08H-01Z-00-DX1 to val/Immune cells
# Copied 40 patches from Stroma of TCGA-A8-A08H-01Z-00-DX1 to val/Stroma
# Copied 72 patches from Tumor of TCGA-A8-A08H-01Z-00-DX1 to val/Tumor
# Copied 500 patches from Adipose of TCGA-XX-A89A-01Z-00-DX1 to val/Adipose
# Copied 500 patches from Background of TCGA-XX-A89A-01Z-00-DX1 to val/Background
# Copied 30 patches from Immune cells of TCGA-XX-A89A-01Z-00-DX1 to val/Immune cells
# Copied 26 patches from Normal of TCGA-XX-A89A-01Z-00-DX1 to val/Normal
# Copied 170 patches from Stroma of TCGA-XX-A89A-01Z-00-DX1 to val/Stroma
# Copied 200 patches from Tumor of TCGA-XX-A89A-01Z-00-DX1 to val/Tumor
# Copied 500 patches from Adipose of TCGA-A2-A0T4-01Z-00-DX1 to val/Adipose
# Copied 500 patches from Background of TCGA-A2-A0T4-01Z-00-DX1 to val/Background
# Copied 60 patches from complex of TCGA-A2-A0T4-01Z-00-DX1 to val/complex
# Copied 27 patches from Immune cells of TCGA-A2-A0T4-01Z-00-DX1 to val/Immune cells
# Copied 47 patches from Normal of TCGA-A2-A0T4-01Z-00-DX1 to val/Normal
# Copied 396 patches from Stroma of TCGA-A2-A0T4-01Z-00-DX1 to val/Stroma
# Copied 230 patches from Tumor of TCGA-A2-A0T4-01Z-00-DX1 to val/Tumor
# Copied 420 patches from Adipose of TCGA-W8-A86G-01Z-00-DX2 to test/Adipose
# Copied 82 patches from Normal of TCGA-W8-A86G-01Z-00-DX2 to test/Normal
# Copied 187 patches from Stroma of TCGA-W8-A86G-01Z-00-DX2 to test/Stroma
# Copied 80 patches from Tumor of TCGA-W8-A86G-01Z-00-DX2 to test/Tumor
# Copied 210 patches from Adipose of TCGA-E2-A15I-01Z-00-DX1 to test/Adipose
# Copied 500 patches from Background of TCGA-E2-A15I-01Z-00-DX1 to test/Background
# Copied 24 patches from Normal of TCGA-E2-A15I-01Z-00-DX1 to test/Normal
# Copied 182 patches from Stroma of TCGA-E2-A15I-01Z-00-DX1 to test/Stroma
# Copied 342 patches from Adipose of TCGA-A2-A25F-01Z-00-DX1 to test/Adipose
# Copied 500 patches from Background of TCGA-A2-A25F-01Z-00-DX1 to test/Background
# Copied 32 patches from complex of TCGA-A2-A25F-01Z-00-DX1 to test/complex
# Copied 67 patches from Immune cells of TCGA-A2-A25F-01Z-00-DX1 to test/Immune cells
# Copied 51 patches from Normal of TCGA-A2-A25F-01Z-00-DX1 to test/Normal
# Copied 239 patches from Stroma of TCGA-A2-A25F-01Z-00-DX1 to test/Stroma
# Copied 94 patches from Tumor of TCGA-A2-A25F-01Z-00-DX1 to test/Tumor
# Copied 500 patches from Adipose of TCGA-3C-AALI-01Z-00-DX2 to test/Adipose
# Copied 500 patches from Background of TCGA-3C-AALI-01Z-00-DX2 to test/Background
# Copied 134 patches from complex of TCGA-3C-AALI-01Z-00-DX2 to test/complex
# Copied 245 patches from Immune cells of TCGA-3C-AALI-01Z-00-DX2 to test/Immune cells
# Copied 15 patches from Necrosis of TCGA-3C-AALI-01Z-00-DX2 to test/Necrosis
# Copied 80 patches from Normal of TCGA-3C-AALI-01Z-00-DX2 to test/Normal
# Copied 500 patches from Stroma of TCGA-3C-AALI-01Z-00-DX2 to test/Stroma
# Copied 320 patches from Tumor of TCGA-3C-AALI-01Z-00-DX2 to test/Tumor
# Data split complete. Check output directory: H:\Optima\Annotations_Split
